# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/raw_sold.csv')

# %%
df.shape
# Out:
# (8232, 29)

# %%
df.head()
# Out:
#                                web-scraper-start-url  \
# 0  https://www.zillow.com/brooklyn-new-york-ny-11...
# 1  https://www.zillow.com/brooklyn-new-york-ny-11...
# 2  https://www.zillow.com/brooklyn-new-york-ny-11...
# 3  https://www.zillow.com/brooklyn-new-york-ny-11...
# 4  https://www.zillow.com/brooklyn-new-york-ny-11...
#
#                                 listing-link  \
# 0           372 E 9th St, Brooklyn, NY 11218
# 1    140 E 2nd St APT 5D, Brooklyn, NY 11218
# 2  260 Ocean Pkwy APT 3C, Brooklyn, NY 11218
# 3           710 E 3rd St, Brooklyn, NY 11218
# 4       152 Stratford Rd, Brooklyn, NY 11218
#
#                                    listing-link-href       price bedrooms  \
# 0  https://www.zillow.com/homedetails/372-E-9th-S...  $2,100,000        4
# 1  https://www.zillow.com/homedetails/140-E-2nd-S...    $615,000        1
# 2  https://www.zillow.com/homedetails/260-Ocean-P...    $750,000        2
# ...

# %%
df_cleaned = pd.read_csv('data/cleaned_sold.csv')

# %%
df_cleaned.shape
# Out:
# (8229, 25)

# %%
df_cleaned.head(10)
# Out:
#                                    listing-link-href  bedrooms  bathrooms  \
# 0  https://www.zillow.com/homedetails/372-E-9th-S...       4.0        5.0
# 1  https://www.zillow.com/homedetails/140-E-2nd-S...       1.0        1.0
# 2  https://www.zillow.com/homedetails/260-Ocean-P...       2.0        1.0
# 3  https://www.zillow.com/homedetails/710-E-3rd-S...       7.0        2.0
# 4  https://www.zillow.com/homedetails/152-Stratfo...       7.0        5.0
# 5  https://www.zillow.com/homedetails/3902-Fort-H...       6.0        2.0
# 6  https://www.zillow.com/homedetails/1105-Cortel...       2.0        3.0
# 7  https://www.zillow.com/homedetails/1202-Cortel...       NaN        NaN
# 8  https://www.zillow.com/homedetails/233-Ocean-P...       2.0        2.0
# 9  https://www.zillow.com/homedetails/488-Ocean-P...       1.0        1.0
#
#    area-sqft                     address          type  built_in  lot_area  \
# 0     2830.0                372 E 9th St  SingleFamily    1925.0       NaN
# ...

# %%
df_photos = pd.read_csv('data/photo_links.csv')

# %%
df_photos.head(10)
# Out:
#    Unnamed: 0                                     main_image-src  \
# 0           0  https://photos.zillowstatic.com/fp/c72c5dddea2...
# 1           1                                                NaN
# 2           2  https://photos.zillowstatic.com/fp/6ce47f3535b...
# 3           3  https://photos.zillowstatic.com/fp/cd33f7698d0...
# 4           4  https://photos.zillowstatic.com/fp/48f379ebb8c...
# 5           5  https://photos.zillowstatic.com/fp/2648b722306...
# 6           6  https://photos.zillowstatic.com/fp/7cfd04c2b6b...
# 7           7                                                NaN
# 8           8  https://photos.zillowstatic.com/fp/bbddf8228cc...
# 9           9                                                NaN
#
#                                           all_images        zpid
# 0  https://photos.zillowstatic.com/fp/c72c5dddea2...    30674686
# 1                                                NaN   418273928
# ...
