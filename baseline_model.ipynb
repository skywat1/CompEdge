# %%
import pandas as pd

pd.set_option('display.max_columns', None)   # show every column, no ... truncation
pd.set_option('display.width', None)         # don't wrap to a fixed width

# %%
# Skip junk rows
df = pd.read_excel('rollingsales_brooklyn.xlsx', header=4)

# %%
df.head(10)
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6359
# 1        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6360
# 2        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6363
# 3        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6364
# 4        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6364
# 5        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6372
# 6        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6374
# 7        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6380
# 8        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6380
# 9        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6408
#
#    LOT  EASEMENT BUILDING CLASS AT PRESENT             ADDRESS  \
# ...

# %%
df.columns = df.columns.str.strip()
df[df['ADDRESS'].str.strip() == '405 SACKETT STREET']
# Out:
#       BOROUGH     NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 7123        3  CARROLL GARDENS  01 ONE FAMILY DWELLINGS                    1
#
#       BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT             ADDRESS  \
# 7123    422   50       NaN                        A4  405 SACKETT STREET
#
#      APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 7123              NaN   11231.0                1.0               0.0
#
#       TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 7123          1.0            2000.0             4219.0      1899.0
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 7123                          1                             A4     7700000
#
#       SALE DATE
# 7123 2025-09-29
